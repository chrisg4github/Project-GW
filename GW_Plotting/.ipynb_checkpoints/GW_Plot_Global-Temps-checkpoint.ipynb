# %%
import pandas as pd
import numpy as np
import scipy as sp
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

# %%
# Store filepath in a variable: use parse_dates=["date"] 
# encoding="ISO-8859-1"
gllo = "./data/clean/clean_GlobalLandOceanTemps.csv"

# Read our Data file with the pandas library
gllo_df = pd.read_csv(gllo,parse_dates=["date"])
print(len(gllo_df.index))
gllo_df.info()
# Out:
# 1992
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1992 entries, 0 to 1991
# Data columns (total 13 columns):
# date                             1992 non-null datetime64[ns]
# land_avg_temp_f                  1992 non-null float64
# land_avg_temp_c                  1992 non-null float64
# land_avg_temp_uncertain          1992 non-null float64
# land_max_temp_f                  1992 non-null float64
# land_max_temp_c                  1992 non-null float64
# land_max_temp_uncertain          1992 non-null float64
# land_min_temp_f                  1992 non-null float64
# land_min_temp_c                  1992 non-null float64
# land_min_temp_uncertain          1992 non-null float64
# land_ocean_avg_temp_f            1992 non-null float64
# land_ocean_avg_temp_c            1992 non-null float64
# land_ocean_avg_temp_uncertain    1992 non-null float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 202.4 KB

# %%
gllo_df.head(5)
# Out:
#         date  land_avg_temp_f  land_avg_temp_c  land_avg_temp_uncertain  \
# 0 1850-01-01          33.3482            0.749                    1.105
# 1 1850-02-01          37.5278            3.071                    1.275
# 2 1850-03-01          40.9172            4.954                    0.955
# 3 1850-04-01          44.9906            7.217                    0.665
# 4 1850-05-01          50.0072           10.004                    0.617
#
#    land_max_temp_f  land_max_temp_c  land_max_temp_uncertain  land_min_temp_f  \
# 0          46.8356            8.242                    1.738          26.2292
# 1          49.9460            9.970                    3.007          27.8762
# 2          50.6246           10.347                    2.401          28.5710
# 3          55.2812           12.934                    1.004          33.8324
# 4          60.1790           15.655                    2.406          38.8598
#
#    land_min_temp_c  land_min_temp_uncertain  land_ocean_avg_temp_f  \
# 0           -3.206                    2.822                55.0994
# 1           -2.291                    1.623                56.4584
# 2           -1.905                    1.410                57.2774
# 3            1.018                    1.329                58.4006
# 4            3.811                    1.347                59.9126
#
#    land_ocean_avg_temp_c  land_ocean_avg_temp_uncertain
# 0                 12.833                          0.367
# 1                 13.588                          0.414
# 2                 14.043                          0.341
# 3                 14.667                          0.267
# 4                 15.507                          0.249

# %%
# Get the min and max date range
gllo_min_date = gllo_df["date"].min()
gllo_max_date = gllo_df["date"].max()
print("min year " + datetime.strftime(gllo_min_date, '%Y-%m-%d') + " max year " + \
      datetime.strftime(gllo_max_date, '%Y-%m-%d'))
# Out:
# min year 1850-01-01 max year 2015-12-01

# %%
gllo_df.corr()
# Out:
#                                land_avg_temp_f  land_avg_temp_c  \
# land_avg_temp_f                       1.000000         1.000000
# land_avg_temp_c                       1.000000         1.000000
# land_avg_temp_uncertain              -0.143129        -0.143129
# land_max_temp_f                       0.995807         0.995807
# land_max_temp_c                       0.995807         0.995807
# land_max_temp_uncertain              -0.108462        -0.108462
# land_min_temp_f                       0.995611         0.995611
# land_min_temp_c                       0.995611         0.995611
# land_min_temp_uncertain              -0.167451        -0.167451
# land_ocean_avg_temp_f                 0.988066         0.988066
# land_ocean_avg_temp_c                 0.988066         0.988066
# land_ocean_avg_temp_uncertain        -0.131412        -0.131412
#
#                                land_avg_temp_uncertain  land_max_temp_f  \
# land_avg_temp_f                              -0.143129         0.995807
# land_avg_temp_c                              -0.143129         0.995807
# land_avg_temp_uncertain                       1.000000        -0.132905
# land_max_temp_f                              -0.132905         1.000000
# land_max_temp_c                              -0.132905         1.000000
# land_max_temp_uncertain                       0.866944        -0.105349
# land_min_temp_f                              -0.165066         0.993404
# land_min_temp_c                              -0.165066         0.993404
# land_min_temp_uncertain                       0.888717        -0.160020
# land_ocean_avg_temp_f                        -0.208008         0.983855
# land_ocean_avg_temp_c                        -0.208008         0.983855
# land_ocean_avg_temp_uncertain                 0.972405        -0.120563
#
#                                land_max_temp_c  land_max_temp_uncertain  \
# land_avg_temp_f                       0.995807                -0.108462
# land_avg_temp_c                       0.995807                -0.108462
# land_avg_temp_uncertain              -0.132905                 0.866944
# land_max_temp_f                       1.000000                -0.105349
# land_max_temp_c                       1.000000                -0.105349
# land_max_temp_uncertain              -0.105349                 1.000000
# land_min_temp_f                       0.993404                -0.123251
# land_min_temp_c                       0.993404                -0.123251
# land_min_temp_uncertain              -0.160020                 0.868702
# land_ocean_avg_temp_f                 0.983855                -0.163396
# land_ocean_avg_temp_c                 0.983855                -0.163396
# land_ocean_avg_temp_uncertain        -0.120563                 0.860425
#
#                                land_min_temp_f  land_min_temp_c  \
# land_avg_temp_f                       0.995611         0.995611
# land_avg_temp_c                       0.995611         0.995611
# land_avg_temp_uncertain              -0.165066        -0.165066
# land_max_temp_f                       0.993404         0.993404
# land_max_temp_c                       0.993404         0.993404
# land_max_temp_uncertain              -0.123251        -0.123251
# land_min_temp_f                       1.000000         1.000000
# land_min_temp_c                       1.000000         1.000000
# land_min_temp_uncertain              -0.185512        -0.185512
# land_ocean_avg_temp_f                 0.986402         0.986402
# land_ocean_avg_temp_c                 0.986402         0.986402
# land_ocean_avg_temp_uncertain        -0.154931        -0.154931
#
#                                land_min_temp_uncertain  land_ocean_avg_temp_f  \
# land_avg_temp_f                              -0.167451               0.988066
# land_avg_temp_c                              -0.167451               0.988066
# land_avg_temp_uncertain                       0.888717              -0.208008
# land_max_temp_f                              -0.160020               0.983855
# land_max_temp_c                              -0.160020               0.983855
# land_max_temp_uncertain                       0.868702              -0.163396
# land_min_temp_f                              -0.185512               0.986402
# land_min_temp_c                              -0.185512               0.986402
# land_min_temp_uncertain                       1.000000              -0.221746
# land_ocean_avg_temp_f                        -0.221746               1.000000
# land_ocean_avg_temp_c                        -0.221746               1.000000
# land_ocean_avg_temp_uncertain                 0.880062              -0.203072
#
#                                land_ocean_avg_temp_c  \
# land_avg_temp_f                             0.988066
# land_avg_temp_c                             0.988066
# land_avg_temp_uncertain                    -0.208008
# land_max_temp_f                             0.983855
# land_max_temp_c                             0.983855
# land_max_temp_uncertain                    -0.163396
# land_min_temp_f                             0.986402
# land_min_temp_c                             0.986402
# land_min_temp_uncertain                    -0.221746
# land_ocean_avg_temp_f                       1.000000
# land_ocean_avg_temp_c                       1.000000
# land_ocean_avg_temp_uncertain              -0.203072
#
#                                land_ocean_avg_temp_uncertain
# land_avg_temp_f                                    -0.131412
# land_avg_temp_c                                    -0.131412
# land_avg_temp_uncertain                             0.972405
# land_max_temp_f                                    -0.120563
# land_max_temp_c                                    -0.120563
# land_max_temp_uncertain                             0.860425
# land_min_temp_f                                    -0.154931
# land_min_temp_c                                    -0.154931
# land_min_temp_uncertain                             0.880062
# land_ocean_avg_temp_f                              -0.203072
# land_ocean_avg_temp_c                              -0.203072
# land_ocean_avg_temp_uncertain                       1.000000

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gllo_df["land_avg_temp_f"]
lag_plot(data)

plt.tight_layout()
plt.savefig("./images/lag-plot_lndavg_tmpf.png")
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gllo_df["land_ocean_avg_temp_f"]
lag_plot(data)

plt.tight_layout()
plt.savefig("./images/lag-plot_lndoceanavg_tmpf.png")
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gllo_df["land_max_temp_f"]
lag_plot(data)

plt.tight_layout()
plt.savefig("./images/lag-plot_lndmax_tmpf.png")
plt.show()

# %%
from pandas.plotting import lag_plot

plt.figure()
data = gllo_df["land_min_temp_f"]
lag_plot(data)

plt.tight_layout()
plt.savefig("./images/lag-plot_lndmin_tmpf.png")
plt.show()

# %%
# create a year column for grouping
gllo_df["year"] = gllo_df["date"].dt.year
print(len(gllo_df.index))
gllo_df.head(5)
# Out:
# 1992
#         date  land_avg_temp_f  land_avg_temp_c  land_avg_temp_uncertain  \
# 0 1850-01-01          33.3482            0.749                    1.105
# 1 1850-02-01          37.5278            3.071                    1.275
# 2 1850-03-01          40.9172            4.954                    0.955
# 3 1850-04-01          44.9906            7.217                    0.665
# 4 1850-05-01          50.0072           10.004                    0.617
#
#    land_max_temp_f  land_max_temp_c  land_max_temp_uncertain  land_min_temp_f  \
# 0          46.8356            8.242                    1.738          26.2292
# 1          49.9460            9.970                    3.007          27.8762
# 2          50.6246           10.347                    2.401          28.5710
# 3          55.2812           12.934                    1.004          33.8324
# 4          60.1790           15.655                    2.406          38.8598
#
#    land_min_temp_c  land_min_temp_uncertain  land_ocean_avg_temp_f  \
# 0           -3.206                    2.822                55.0994
# 1           -2.291                    1.623                56.4584
# 2           -1.905                    1.410                57.2774
# 3            1.018                    1.329                58.4006
# 4            3.811                    1.347                59.9126
#
#    land_ocean_avg_temp_c  land_ocean_avg_temp_uncertain  year
# 0                 12.833                          0.367  1850
# 1                 13.588                          0.414  1850
# 2                 14.043                          0.341  1850
# 3                 14.667                          0.267  1850
# 4                 15.507                          0.249  1850

# %%
gllo_avg_df = gllo_df.groupby(["year"],\
              as_index=False)["land_avg_temp_f","land_max_temp_f",
              "land_min_temp_f","land_ocean_avg_temp_f"].mean().\
              rename(columns={"land_avg_temp_f": "ylylndavg_tmpf",
                        "land_max_temp_f": "ylylndmax_tmpf",
                        "land_min_temp_f": "ylylndmin_tmpf",
                        "land_ocean_avg_temp_f": "ylylndocnavg_tmpf"})        
gllo_avg_df.head(5)
# Out:
#    year  ylylndavg_tmpf  ylylndmax_tmpf  ylylndmin_tmpf  ylylndocnavg_tmpf
# 0  1850        46.22120        56.25800        35.53580            58.7609
# 1  1851        46.72145        55.54580        35.96705            58.9853
# 2  1852        46.58030        56.11520        36.20660            59.0117
# 3  1853        46.47530        56.99585        35.40650            58.9193
# 4  1854        46.77890        57.15935        35.17190            58.9838

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)

x_axis = gllo_avg_df["year"]  
y1_axis = gllo_avg_df["ylylndavg_tmpf"]

ax.set_title("Global Yealy Land Temperatures(F) ",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2015").set_fontsize('14')
ax.set_ylabel("Global Yearly Temps(F)").set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
fig.autofmt_xdate(rotation=45, ha='right')
# ax.xaxis.set_major_locator(mdates.YearLocator())
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

ax.plot(x_axis, y1_axis, color="purple", linewidth= 1)

ax.legend(["Land Avg(F)"], loc="best")

plt.tight_layout()
plt.savefig("./images/1850-2015_yearly_land_avg_temps.png")
plt.show()

# %%
# Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, date, time
import matplotlib.dates as mdates

fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)

x_axis = gllo_avg_df["year"]  
y1_axis = gllo_avg_df["ylylndavg_tmpf"]
y2_axis = gllo_avg_df["ylylndmax_tmpf"]
y3_axis = gllo_avg_df["ylylndmin_tmpf"]
y4_axis = gllo_avg_df["ylylndocnavg_tmpf"]

ax.set_title("Global Yealy Temperatures(F) ",\
             weight='bold').set_fontsize('18')
ax.set_xlabel("1850 - 2015", weight='bold').set_fontsize('14')
ax.set_ylabel("Global Yearly Temps(F)", 
              weight='bold').set_fontsize('14')

ax.grid(True)
ax.set_facecolor("whitesmoke")
fig.autofmt_xdate(rotation=45, ha='right')
# ax.xaxis.set_major_locator(mdates.YearLocator())
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

ax.plot(x_axis, y1_axis, color="purple", linewidth= 1)
ax.plot(x_axis, y2_axis, color="red", linewidth= 1)
ax.plot(x_axis, y3_axis, color="limegreen", linewidth= 1)
ax.plot(x_axis, y4_axis, color="black", linewidth= 1)


ax.legend(["Land Avg(F)","Land Max(F)","Land Min(F)",
           "Land Ocean Avg(F)"], loc="best",
           bbox_to_anchor=(1, 0.75))

plt.tight_layout()
plt.savefig("./images/1850-2015_yearly_temps.png")
plt.show()
